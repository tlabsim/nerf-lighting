# %% [markdown]
# # NeRF Test

# %%
import sys, os
__basedir__ = os.path.dirname(os.path.realpath('.'))
print(__basedir__)
if __basedir__ not in sys.path:
     sys.path.insert(0, __basedir__)

os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'
# Out:
# d:\NeRF\nerf-lighting

# %%
import tensorflow as tf
import numpy as np
import imageio
import json
import random
import time
import cv2

from run_nerf_helpers import *
from nerf_renderer import *
from misc_helpers import *
from load_llff import load_llff_data

import matplotlib.pyplot as plt

# %%
HEIRARCHICAL_SAMPLING_METHOD = 2

# %%
def load_data(args):
    datadir = os.path.normcase(os.path.join(__basedir__, args.datadir))
    images, poses, bds, render_poses, i_test = load_llff_data(datadir, args.factor,
                                                                  recenter=True, bd_factor=.75,
                                                                  spherify=args.spherify)
    hwf = poses[0, :3, -1]
    H, W, focal = hwf
    H, W = int(H), int(W)

    poses = poses[:, :3, :4]
    print('Loaded llff', images.shape,
            render_poses.shape, hwf, args.datadir)

    print('DEFINING BOUNDS')
    if args.no_ndc:
        near = tf.reduce_min(bds) * .9
        far = tf.reduce_max(bds) * 1.
    else:
        near = 0.
        far = 1.
    print('NEAR FAR', near, far)   

    return images, poses, H, W, focal, near, far, bds, render_poses

# %%
args_file = '../data/rubiks_rgba2/logs/rubiks_rgba2/args.txt'
args = ConfigReader(args_file)

embed_fn, input_ch = get_embedder(args.multires, args.i_embed)

input_ch_views = 0
embeddirs_fn = None
if args.use_viewdirs:
    embeddirs_fn, input_ch_views = get_embedder(
        args.multires_views, args.i_embed)
output_ch = 4
skips = [4]
model = init_nerf_model(
    D=args.netdepth, W=args.netwidth,
    input_ch=input_ch, output_ch=output_ch, skips=skips,
    input_ch_views=input_ch_views, LL=4, use_viewdirs=args.use_viewdirs)

model_fine = None
model_fine = init_nerf_model(
    D=args.netdepth_fine, W=args.netwidth_fine,
    input_ch=input_ch, output_ch=output_ch, skips=skips,
    input_ch_views=input_ch_views, LL=4, use_viewdirs=args.use_viewdirs)

def network_query_fn(inputs, viewdirs, network_fn): return run_network(
    inputs, viewdirs, network_fn,
    embed_fn=embed_fn,
    embeddirs_fn=embeddirs_fn,
    netchunk=args.netchunk)

render_kwargs = {
    'network_query_fn': network_query_fn,
    'perturb': args.perturb,
    'N_importance': args.N_importance,
    'network_fine': model_fine,
    'N_samples': args.N_samples,
    'network_fn': model,
    'use_viewdirs': args.use_viewdirs,
    'white_bkgd': args.white_bkgd,
    'raw_noise_std': args.raw_noise_std,
    'chunk': args.chunk,
    'ndc': False,
    'lindisp': args.lindisp
}

print(render_kwargs)
# Out:
# MODEL_NERF 63 27 <class 'int'> <class 'int'> True
# (None, 90) (None, 63) (None, 27)
# MODEL_NERF 63 27 <class 'int'> <class 'int'> True
# (None, 90) (None, 63) (None, 27)
# {'network_query_fn': <function network_query_fn at 0x0000024B2E3E79D8>, 'perturb': 1.0, 'N_importance': 128, 'network_fine': <tensorflow.python.keras.engine.functional.Functional object at 0x0000024B34510648>, 'N_samples': 64, 'network_fn': <tensorflow.python.keras.engine.functional.Functional object at 0x0000024B2E3D4788>, 'use_viewdirs': True, 'white_bkgd': False, 'raw_noise_std': 1.0, 'chunk': 32768, 'ndc': False, 'lindisp': False}

# %%
model_coarse_weights_file = '../data/rubiks_rgba2/logs/rubiks_rgba2/model_650000.npy'
model_fine_weights_file = '../data/rubiks_rgba2/logs/rubiks_rgba2/model_fine_650000.npy'

model.set_weights(np.load(model_coarse_weights_file, allow_pickle=True))
model_fine.set_weights(np.load(model_fine_weights_file, allow_pickle=True))

# %%
images, poses, H, W, focal, near, far, bds, render_poses = load_data(args)
# Out:
# Loaded image data (500, 500, 3, 132) [ 500.         500.        1098.8775858]
# Loaded ./data/rubiks_rgba2/ 2.2962166918186226 11.288918670814095
# Data:
# (132, 3, 5) (132, 500, 500, 3) (132, 2)
# HOLDOUT view is 128
# Loaded llff (132, 500, 500, 3) (120, 3, 5) [ 500.      500.     1098.8776] ./data/rubiks_rgba2/
# DEFINING BOUNDS
# NEAR FAR tf.Tensor(0.46544135, shape=(), dtype=float32) tf.Tensor(2.5425055, shape=(), dtype=float32)

# %%
i = 82
rgb, disp, acc, _ = render(H, W, focal, near=near, far=far, c2w=poses[i, :3, :4], retraw=False, **render_kwargs)

# %%
plot_images([images[i], rgb, acc], 1, 3)

# %%
plt.imsave(f'../outputs/acc_test/{i}_original.png', images[i])
plt.imsave(f'../outputs/acc_test/{i}_rgb.png', rgb.numpy())
plt.imsave(f'../outputs/acc_test/{i}_acc.png', acc.numpy(), cmap='gray')

# %%
def get_psnr(images, poses, near, far):
    rgbs = []
    psnrs = []    
    for i, target in enumerate(images):
        print('Rendering ', i + 1)
        rgb, _, _, _ = render(H, W, focal, near=near, far=far, c2w=poses[i, :3, :4], retraw=False, **render_kwargs)
        rgbs.append(rgb)
        psnr = mse2psnr(img2mse(rgb, target))
        psnrs.append(psnr)
        del rgb

    return rgbs, psnrs

# %%
test_images = images[::8]
test_poses = poses[::8]
test_images.shape, test_poses.shape
# Out:
# ((17, 500, 500, 3), (17, 3, 4))

# %%
rgbs, psnrs = get_psnr(images, poses, near, far)
# Out:
# Rendering  1
# 1
# Rendering  2
# 1
# Rendering  3
# 1
# Rendering  4
# 1
# Rendering  5
# 1
# Rendering  6
# 1
# Rendering  7
# 1
# Rendering  8
# 1
# Rendering  9
# 1
# Rendering  10
# 1
# Rendering  11
# 1
# Rendering  12
# 1
# Rendering  13
# 1
# Rendering  14
# 1
# Rendering  15
# 1
# Rendering  16
# 1
# Rendering  17
# 1
# Rendering  18
# 1
# Rendering  19
# 1
# Rendering  20
# 1
# Rendering  21
# 1
# Rendering  22
# 1
# Rendering  23
# 1
# Rendering  24
# 1
# Rendering  25
# 1
# Rendering  26
# 1
# Rendering  27
# 1
# Rendering  28
# 1
# Rendering  29
# 1
# Rendering  30
# 1
# Rendering  31
# 1
# Rendering  32
# 1
# Rendering  33
# 1
# Rendering  34
# 1
# Rendering  35
# 1
# Rendering  36
# 1
# Rendering  37
# 1
# Rendering  38
# 1
# Rendering  39
# 1
# Rendering  40
# 1
# Rendering  41
# 1
# Rendering  42
# 1
# Rendering  43
# 1
# Rendering  44
# 1
# Rendering  45
# 1
# Rendering  46
# 1
# Rendering  47
# 1
# Rendering  48
# 1
# Rendering  49
# 1
# Rendering  50
# 1
# Rendering  51
# 1
# Rendering  52
# 1
# Rendering  53
# 1
# Rendering  54
# 1
# Rendering  55
# 1
# Rendering  56
# 1
# Rendering  57
# 1
# Rendering  58
# 1
# Rendering  59
# 1
# Rendering  60
# 1
# Rendering  61
# 1
# Rendering  62
# 1
# Rendering  63
# 1
# Rendering  64
# 1
# Rendering  65
# 1
# Rendering  66
# 1
# Rendering  67
# 1
# Rendering  68
# 1
# Rendering  69
# 1
# Rendering  70
# 1
# Rendering  71
# 1
# Rendering  72
# 1
# Rendering  73
# 1
# Rendering  74
# 1
# Rendering  75
# 1
# Rendering  76
# 1
# Rendering  77
# 1
# Rendering  78
# 1
# Rendering  79
# 1
# Rendering  80
# 1
# Rendering  81
# 1
# Rendering  82
# 1
# Rendering  83
# 1
# Rendering  84
# 1
# Rendering  85
# 1
# Rendering  86
# 1
# Rendering  87
# 1
# Rendering  88
# 1
# Rendering  89
# 1
# Rendering  90
# 1
# Rendering  91
# 1
# Rendering  92
# 1
# Rendering  93
# 1
# Rendering  94
# 1
# Rendering  95
# 1
# Rendering  96
# 1
# Rendering  97
# 1
# Rendering  98
# 1
# Rendering  99
# 1
# Rendering  100
# 1
# Rendering  101
# 1
# Rendering  102
# 1
# Rendering  103
# 1
# Rendering  104
# 1
# Rendering  105
# 1
# Rendering  106
# 1
# Rendering  107
# 1
# Rendering  108
# 1
# Rendering  109
# 1
# Rendering  110
# 1
# Rendering  111
# 1
# Rendering  112
# 1
# Rendering  113
# 1
# Rendering  114
# 1
# Rendering  115
# 1
# Rendering  116
# 1
# Rendering  117
# 1
# Rendering  118
# 1
# Rendering  119
# 1
# Rendering  120
# 1
# Rendering  121
# 1
# Rendering  122
# 1
# Rendering  123
# 1
# Rendering  124
# 1
# Rendering  125
# 1
# Rendering  126
# 1
# Rendering  127
# 1
# Rendering  128
# 1
# Rendering  129
# 1
# Rendering  130
# 1
# Rendering  131
# 1
# Rendering  132
# 1

# %%
plot_images(rgbs, 1, 1)

# %%
psnrs
# Out:
# [<tf.Tensor: shape=(), dtype=float32, numpy=29.12305>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=30.803484>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.408445>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.83948>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.76444>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.708092>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.84049>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.149307>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=29.304049>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=30.76422>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=30.53245>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=30.757769>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.326279>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.174168>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=30.984243>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=30.847712>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=26.082506>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=28.63612>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=21.250195>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=28.67819>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=30.580992>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.07396>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.815964>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.539106>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=29.803919>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.664637>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.32302>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.11877>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.38489>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.283255>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.18743>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=30.902868>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.132746>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.26904>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.771084>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.89482>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.566833>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.963436>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.80158>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.541737>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=30.537315>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.34972>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.317432>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.54925>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.577713>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.842987>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.26861>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.786127>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=29.16677>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.10772>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.071424>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.354877>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.598555>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.15016>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.75734>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.57143>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=29.392113>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.601759>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.931402>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.039608>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.165436>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.3723>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.69135>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.370758>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=30.599215>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.46839>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=33.044857>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=33.240196>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=33.06359>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.828926>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=33.306>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.641647>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=30.705593>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.38654>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.465992>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.68314>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.563087>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.58792>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.486378>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.741495>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=28.404804>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.025974>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.74523>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.891045>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.188103>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.135094>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.464016>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.029343>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=30.274807>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.359745>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.496655>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.476963>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.829044>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.37944>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.393063>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.79112>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.301958>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.825108>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.839275>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=33.017048>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=33.08884>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.78979>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.850723>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.291805>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=30.297768>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.06471>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.43004>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.48826>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=33.0963>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=33.311245>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.498028>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.65027>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=29.89691>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.775507>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.703812>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.887712>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.023148>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.328686>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.18796>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.766968>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=30.037172>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.05015>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.188957>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=31.929146>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.44037>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.87689>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.88131>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=32.582577>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=21.572659>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=17.800135>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=29.899063>,
#  <tf.Tensor: shape=(), dtype=float32, numpy=29.407053>]

# %%
plt.imsave('../outputs/res_sampling_test_img82.png', images[82])

# %%
mean_psnr = lambda x: tf.reduce_mean(x).numpy()

# %%
plot_images(rgbs, 14, 10, scale=1.0)

# %%
plot_images(rgbs[128:], 2, 2)

# %%
mean_psnr(psnrs)
# Out:
# 31.461681

# %%
mean_psnr(psnrs[::8])
# Out:
# 30.035856

# %%
i_test = np.arange(images.shape[0])[::8]
i_train = np.array([i for i in np.arange(int(images.shape[0])) if  i not in i_test])
train_psnrs = [psnrs[i] for i in i_train]

# %%
mean_psnr(psnrs[::8])
# Out:
# 29.272549
